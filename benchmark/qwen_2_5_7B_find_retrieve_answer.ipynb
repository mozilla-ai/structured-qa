# %% [markdown]
# # Structured Q&A

# %% [markdown]
# Source code: https://github.com/mozilla-ai/structured-qa

# %% [markdown]
# Docs: https://mozilla-ai.github.io/structured-qa

# %% [markdown]
# ## Installing dependencies

# %%
# %pip install git+https://github.com/mozilla-ai/structured-qa.git@5-add-benchmark
# Out:
# Collecting git+https://github.com/mozilla-ai/structured-qa.git@5-add-benchmark
#   Cloning https://github.com/mozilla-ai/structured-qa.git (to revision 5-add-benchmark) to /tmp/pip-req-build-zpym8juf
#   Running command git clone --filter=blob:none --quiet https://github.com/mozilla-ai/structured-qa.git /tmp/pip-req-build-zpym8juf
#   Running command git checkout -b 5-add-benchmark --track origin/5-add-benchmark
#   Switched to a new branch '5-add-benchmark'
#   Branch '5-add-benchmark' set up to track remote branch '5-add-benchmark' from 'origin'.
#   Resolved https://github.com/mozilla-ai/structured-qa.git to commit 7b9c96cd5fc3cd34781aa26e2519a6f4731feedc
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: fire in /usr/local/lib/python3.11/dist-packages (from structured-qa==0.3.3.dev84+g7b9c96c) (0.7.0)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.11/dist-packages (from structured-qa==0.3.3.dev84+g7b9c96c) (0.27.1)
# Requirement already satisfied: loguru in /usr/local/lib/python3.11/dist-packages (from structured-qa==0.3.3.dev84+g7b9c96c) (0.7.3)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.11/dist-packages (from structured-qa==0.3.3.dev84+g7b9c96c) (2.10.6)
# Requirement already satisfied: pymupdf4llm in /usr/local/lib/python3.11/dist-packages (from structured-qa==0.3.3.dev84+g7b9c96c) (0.0.17)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from structured-qa==0.3.3.dev84+g7b9c96c) (6.0.2)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.11/dist-packages (from structured-qa==0.3.3.dev84+g7b9c96c) (3.11.0)
# Requirement already satisfied: streamlit in /usr/local/lib/python3.11/dist-packages (from structured-qa==0.3.3.dev84+g7b9c96c) (1.41.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from fire->structured-qa==0.3.3.dev84+g7b9c96c) (2.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->structured-qa==0.3.3.dev84+g7b9c96c) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->structured-qa==0.3.3.dev84+g7b9c96c) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->structured-qa==0.3.3.dev84+g7b9c96c) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->structured-qa==0.3.3.dev84+g7b9c96c) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->structured-qa==0.3.3.dev84+g7b9c96c) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->structured-qa==0.3.3.dev84+g7b9c96c) (4.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->structured-qa==0.3.3.dev84+g7b9c96c) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic->structured-qa==0.3.3.dev84+g7b9c96c) (2.27.2)
# Requirement already satisfied: pymupdf>=1.24.10 in /usr/local/lib/python3.11/dist-packages (from pymupdf4llm->structured-qa==0.3.3.dev84+g7b9c96c) (1.25.2)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.11/dist-packages (from streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (1.26.4)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (2.2.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (11.1.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /usr/local/lib/python3.11/dist-packages (from streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (4.25.6)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (17.0.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (13.9.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (0.10.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.11/dist-packages (from streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.11/dist-packages (from streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.11/dist-packages (from streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.11/dist-packages (from streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (6.3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (3.1.5)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (1.23.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub->structured-qa==0.3.3.dev84+g7b9c96c) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub->structured-qa==0.3.3.dev84+g7b9c96c) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub->structured-qa==0.3.3.dev84+g7b9c96c) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub->structured-qa==0.3.3.dev84+g7b9c96c) (2024.12.14)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich<14,>=10.14.0->streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich<14,>=10.14.0->streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (2.18.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->altair<6,>=4.0->streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (0.36.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (0.22.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit->structured-qa==0.3.3.dev84+g7b9c96c) (1.17.0)

# %%
# !wget https://raw.githubusercontent.com/mozilla-ai/structured-qa/refs/heads/5-add-benchmark/benchmark/structured_qa.csv
# Out:
# --2025-01-29 13:54:23--  https://raw.githubusercontent.com/mozilla-ai/structured-qa/refs/heads/5-add-benchmark/benchmark/structured_qa.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21734 (21K) [text/plain]
# Saving to: ‘structured_qa.csv.3’
#
# structured_qa.csv.3 100%[===================>]  21.22K  --.-KB/s    in 0.002s
#
# 2025-01-29 13:54:24 (9.19 MB/s) - ‘structured_qa.csv.3’ saved [21734/21734]

# %% [markdown]
# # Setup

# %%
import os

os.environ["LOGURU_LEVEL"] = "INFO"

# %%
from loguru import logger

# %% [markdown]
# ## Function to Process a single Document

# %%
from structured_qa.config import FIND_PROMPT
from structured_qa.preprocessing import document_to_sections_dir
from structured_qa.workflow import find_retrieve_answer


ANSWER_WITH_TYPE_PROMPT = """
You are a rigorous assistant answering questions.
You only answer based on the current information available.
The current information available is:

```
{CURRENT_INFO}
```

The answer must be in one of the following formats:
- YES/NO (for boolean questions)
Is the model an LLM?
YES
- Number (for numeric questions)
How many layers does the model have?
12
- Single letter (for multiple-choice questions)
What is the activation function used in the model? -A: ReLU -B: Sigmoid -C: Tanh
C
"""


def process_document(
    document_file,
    document_data,
    model,
    find_prompt: str = FIND_PROMPT,
    answer_prompt: str = ANSWER_WITH_TYPE_PROMPT,
):
    sections_dir = Path("sections") / Path(document_file).stem
    if not sections_dir.exists():
        logger.info("Splitting document into sections")
        document_to_sections_dir(document_file, sections_dir)

    logger.info("Predicting")
    answers = {}
    sections = {}
    for index, row in document_data.iterrows():
        question = row["question"]
        logger.info(f"Question: {question}")
        answer, sections_checked = find_retrieve_answer(
            question, model, sections_dir, find_prompt, answer_prompt
        )
        logger.info(f"Answer: {answer}")
        answers[index] = answer
        sections[index] = sections_checked[-1] if sections_checked else None

    return answers, sections

# %% [markdown]
# ## Load Model

# %%
from structured_qa.model_loaders import load_llama_cpp_model

# %%
model = load_llama_cpp_model(
    "bartowski/Qwen2.5-7B-Instruct-GGUF/Qwen2.5-7B-Instruct-Q8_0.gguf"
)

# %% [markdown]
# # Run Benchmark

# %%
from pathlib import Path
from urllib.request import urlretrieve

import pandas as pd

logger.info("Loading input data")
data = pd.read_csv("structured_qa.csv")
data["pred_answer"] = [None] * len(data)
data["pred_section"] = [None] * len(data)

for document_link, document_data in data.groupby("document"):
    logger.info(f"Downloading document {document_link}")
    downloaded_document = Path(f"{Path(document_link).name}.pdf")
    if not Path(downloaded_document).exists():
        urlretrieve(document_link, downloaded_document)
        logger.info(f"Downloaded {document_link} to {downloaded_document}")
    else:
        logger.info(f"File {downloaded_document} already exists")

    answers, sections = process_document(downloaded_document, document_data, model)

    for index in document_data.index:
        data.loc[index, "pred_answer"] = str(answers[index]).upper()
        data.loc[index, "pred_section"] = sections[index]

data.to_csv("results.csv")
# Out:
# 2025-01-29 13:54:26.672 | INFO     | __main__:<cell line: 0>:6 - Loading input data
# 2025-01-29 13:54:26.682 | INFO     | __main__:<cell line: 0>:12 - Downloading document https://aiindex.stanford.edu/wp-content/uploads/2024/05/HAI_AI-Index-Report-2024.pdf
# 2025-01-29 13:54:26.686 | INFO     | __main__:<cell line: 0>:18 - File HAI_AI-Index-Report-2024.pdf.pdf already exists
# 2025-01-29 13:54:26.687 | INFO     | __main__:process_document:40 - Predicting
# 2025-01-29 13:54:26.689 | INFO     | __main__:process_document:45 - Question: which type of risk was identified as the leading concern globally? -A: Fairness risks. -B: Privacy and data governance risks. -C: Risks related to generative AI deployment.
# 2025-01-29 13:54:27.691 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 988.13ms
# 2025-01-29 13:54:27.701 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:27.702 | INFO     | __main__:process_document:45 - Question: In which geographical area were fairness risks selected by the smallest percentage of respondents? -A: Asia. -B: Europe. -C: North America.
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 540.84ms
# 2025-01-29 13:54:28.263 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:28.271 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:28.274 | INFO     | __main__:process_document:45 - Question: What is a major consequence of the rising training costs for foundation models? -A: The exclusion of universities from developing leading-edge foundation models. -B: Increased collaboration between universities and AI companies. -C: A decrease in the number of policy initiatives related to AI research.
# 2025-01-29 13:54:28.870 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 572.93ms
# 2025-01-29 13:54:28.875 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:28.879 | INFO     | __main__:process_document:45 - Question: How the AI Index and Epoch AI estimated training costs for foundation models? -A: By surveying AI companies on their reported expenses. -B: By analyzing government funding allocated to AI research. -C: By analyzing training duration, hardware type, quantity, and utilization rate.
# 2025-01-29 13:54:29.418 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 521.13ms
# 2025-01-29 13:54:29.427 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:29.430 | INFO     | __main__:process_document:45 - Question: What is a major source of inequality in AI related to tokenization? -A: The significant variability in the number of tokens required to represent the same content across different languages. -B: The uniform processing speed of all languages. -C: The consistent cost of inference across different languages.
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 653.13ms
# 2025-01-29 13:54:30.095 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:30.100 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:30.103 | INFO     | __main__:process_document:45 - Question: What are the three major inequalities resulting from variable tokenization? -A: Increased model training costs, limited access to resources, and biased results. -B: Higher inference costs, longer processing times, and reduced available context for the model. -C:  Limited language support, increased hardware requirements, and data bias.
# 2025-01-29 13:54:30.948 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 829.04ms
# 2025-01-29 13:54:30.951 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:30.953 | INFO     | __main__:process_document:45 - Question: How many AI-related regulations were enacted in the United States in 2023?
# 2025-01-29 13:54:31.576 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 615.85ms
# 2025-01-29 13:54:31.583 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:31.587 | INFO     | __main__:process_document:45 - Question: Which of the following was identified as a high relevance AI regulation? -A: Securities and Exchange Commission’s Cybersecurity Risk Management Strategy. -B: Copyright Office and Library of Congress’ Copyright Registration Guidance. -C: Regulations related to foreign trade and international finance
# 2025-01-29 13:54:32.208 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 613.00ms
# 2025-01-29 13:54:32.211 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:32.214 | INFO     | __main__:process_document:45 - Question: Which country had the highest proportion of female bachelor's graduates in informatics, computer science, computer engineering, and information technology among the surveyed European nations? -A: France. -B: Bulgaria. -C: United Kingdom
# 2025-01-29 13:54:32.858 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 626.48ms
# 2025-01-29 13:54:32.866 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:32.867 | INFO     | __main__:process_document:45 - Question: Which countries reported the smallest proportion of female master's graduates in informatics, CS, CE, and IT as of 2022? -A: Estonia, Romania, and Bulgaria. -B: United Kingdom, Germany, and Switzerland. -C: Belgium, Italy, and Switzerland.
# 2025-01-29 13:54:33.431 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 554.99ms
# 2025-01-29 13:54:33.442 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:33.466 | INFO     | __main__:<cell line: 0>:12 - Downloading document https://arxiv.org/pdf/1706.03762
# 2025-01-29 13:54:33.471 | INFO     | __main__:<cell line: 0>:18 - File 1706.03762.pdf already exists
# 2025-01-29 13:54:33.478 | INFO     | __main__:process_document:40 - Predicting
# 2025-01-29 13:54:33.481 | INFO     | __main__:process_document:45 - Question: What type of architecture does the model use? -A: decoder only -B: encoder only -C: encoder-decoder
# 2025-01-29 13:54:34.056 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 568.57ms
# 2025-01-29 13:54:34.061 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:34.063 | INFO     | __main__:process_document:45 - Question: How many layers compose the encoder?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 689.37ms
# 2025-01-29 13:54:34.770 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:34.772 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:34.774 | INFO     | __main__:process_document:45 - Question: How many layers compose the decoder?
# 2025-01-29 13:54:35.397 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 613.50ms
# 2025-01-29 13:54:35.399 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:35.401 | INFO     | __main__:process_document:45 - Question: How many parallel attention heads are used?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 582.09ms
# 2025-01-29 13:54:35.992 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:35.994 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:35.996 | INFO     | __main__:process_document:45 - Question: Does the final model use learned embeddings for the input and output tokens?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 607.49ms
# 2025-01-29 13:54:36.611 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:36.614 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:36.616 | INFO     | __main__:process_document:45 - Question: Does the final model use learned positional embeddings?
# 2025-01-29 13:54:37.234 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 610.46ms
# 2025-01-29 13:54:37.237 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:37.239 | INFO     | __main__:process_document:45 - Question: How many GPUs were used for training?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 583.15ms
# 2025-01-29 13:54:37.831 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:37.832 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:37.836 | INFO     | __main__:process_document:45 - Question: What type of GPUs were used for training? -A: NVIDIA A100 -B: NVIDIA P100 -C: NVIDIA T4
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 609.22ms
# 2025-01-29 13:54:38.452 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:38.453 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:38.455 | INFO     | __main__:process_document:45 - Question: What optimizer was used for training? -A: AdamW -B: Adam -C: SGD
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 632.94ms
# 2025-01-29 13:54:39.100 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:39.102 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:39.103 | INFO     | __main__:process_document:45 - Question: How many warmup steps were used?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 661.72ms
# 2025-01-29 13:54:39.770 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:39.772 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:39.773 | INFO     | __main__:process_document:45 - Question: What was the dropout rate used for the base model?
# 2025-01-29 13:54:40.339 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 558.40ms
# 2025-01-29 13:54:40.341 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:40.350 | INFO     | __main__:<cell line: 0>:12 - Downloading document https://arxiv.org/pdf/2106.09685.pdf
# 2025-01-29 13:54:40.354 | INFO     | __main__:<cell line: 0>:18 - File 2106.09685.pdf.pdf already exists
# 2025-01-29 13:54:40.355 | INFO     | __main__:process_document:40 - Predicting
# 2025-01-29 13:54:40.359 | INFO     | __main__:process_document:45 - Question: Does LoRA work with any neural network containing dense layers?
# 2025-01-29 13:54:41.023 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 659.57ms
# 2025-01-29 13:54:41.025 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:41.027 | INFO     | __main__:process_document:45 - Question: By how much can LoRA reduce GPU memory requirements during training? -A: 10x, -B: 5x, -C: 3x
# 2025-01-29 13:54:41.666 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 635.63ms
# 2025-01-29 13:54:41.668 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:41.670 | INFO     | __main__:process_document:45 - Question: In billions, how many trainable parameters does GPT-3 have?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 632.74ms
# 2025-01-29 13:54:42.310 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:42.311 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:42.313 | INFO     | __main__:process_document:45 - Question: Does LoRA introduce additional inference latency compared to full fine-tuning?
# 2025-01-29 13:54:42.904 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 584.31ms
# 2025-01-29 13:54:42.906 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:42.909 | INFO     | __main__:<cell line: 0>:12 - Downloading document https://arxiv.org/pdf/2201.11903
# 2025-01-29 13:54:42.914 | INFO     | __main__:<cell line: 0>:18 - File 2201.11903.pdf already exists
# 2025-01-29 13:54:42.917 | INFO     | __main__:process_document:40 - Predicting
# 2025-01-29 13:54:42.920 | INFO     | __main__:process_document:45 - Question: Is Arithmetic reasoning is a task that language models often find very easy?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 658.44ms
# 2025-01-29 13:54:43.588 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:43.591 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:43.593 | INFO     | __main__:process_document:45 - Question: How many large language models were evaluated?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 481.89ms
# 2025-01-29 13:54:44.083 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:44.086 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:44.088 | INFO     | __main__:process_document:45 - Question: How many benchmarks were used to evaluate arithmetic reasoning?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 660.08ms
# 2025-01-29 13:54:44.754 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:44.758 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:44.759 | INFO     | __main__:process_document:45 - Question: Is symbolic reasoning usually simple for humans but challenging for language models?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 557.92ms
# 2025-01-29 13:54:45.329 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:45.332 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:45.333 | INFO     | __main__:process_document:45 - Question: How many words have the example names that the model has seen for letter concatenation? -A: 3 -B: 2 -C: 4
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 636.75ms
# 2025-01-29 13:54:45.976 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:45.978 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:45.982 | INFO     | __main__:process_document:45 - Question: Which symbolic reasoning task is used as an out-of-domain evaluation? -A: Coin Flip -B: Tower of Hanoi -C: Chess puzzles
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 608.68ms
# 2025-01-29 13:54:46.600 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:46.602 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:46.604 | INFO     | __main__:process_document:45 - Question: How many annotators provided independent chains of thought?
# 2025-01-29 13:54:47.296 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 686.39ms
# 2025-01-29 13:54:47.299 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:47.301 | INFO     | __main__:process_document:45 - Question: How many random samples were examined to understand model performance?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 607.93ms
# 2025-01-29 13:54:47.915 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:47.917 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:47.923 | INFO     | __main__:<cell line: 0>:12 - Downloading document https://arxiv.org/pdf/2210.05189
# 2025-01-29 13:54:47.928 | INFO     | __main__:<cell line: 0>:18 - File 2210.05189.pdf already exists
# 2025-01-29 13:54:47.929 | INFO     | __main__:process_document:40 - Predicting
# 2025-01-29 13:54:47.932 | INFO     | __main__:process_document:45 - Question: Can recurrent networks also be converted to decision trees?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 635.76ms
# 2025-01-29 13:54:48.574 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:48.578 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:48.579 | INFO     | __main__:process_document:45 - Question: How many layers are in the toy model (y = x^2)?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 582.96ms
# 2025-01-29 13:54:49.168 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:49.170 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:49.172 | INFO     | __main__:process_document:45 - Question: Does the toy model (y = x^2) use Sigmoid activation function?
# 2025-01-29 13:54:49.864 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 685.88ms
# 2025-01-29 13:54:49.866 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:49.868 | INFO     | __main__:process_document:45 - Question: How many parameters are in the toy model (y = x^2) tree?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 559.12ms
# 2025-01-29 13:54:50.436 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:50.437 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:50.439 | INFO     | __main__:process_document:45 - Question: How many layers are in the half-moon neural network?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 607.69ms
# 2025-01-29 13:54:51.056 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:51.057 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:51.060 | INFO     | __main__:process_document:45 - Question: What is the main computational advantage of decision trees? -A: Less storage memory, -B: Fewer operations, -C: Lower accuracy
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 608.10ms
# 2025-01-29 13:54:51.676 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:51.678 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:51.683 | INFO     | __main__:<cell line: 0>:12 - Downloading document https://authorsalliance.org/wp-content/uploads/Documents/Guides/Authors%20Alliance%20-%20Understanding%20Open%20Access.pdf
# 2025-01-29 13:54:51.687 | INFO     | __main__:<cell line: 0>:18 - File Authors%20Alliance%20-%20Understanding%20Open%20Access.pdf.pdf already exists
# 2025-01-29 13:54:51.689 | INFO     | __main__:process_document:40 - Predicting
# 2025-01-29 13:54:51.691 | INFO     | __main__:process_document:45 - Question: According to the guide, what is the typical license used to grant reuse rights with libre open access? -A: GNU General Public License -B: Creative Commons license -C: MIT license
# 2025-01-29 13:54:52.359 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 659.73ms
# 2025-01-29 13:54:52.361 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:52.364 | INFO     | __main__:process_document:45 - Question: how many peer-reviewed open access journals are indexed by the Directory of Open Access Journals (DOAJ)? -A: Over 10,000 -B: Over 20,000 -C: Exactly 30,000
# 2025-01-29 13:54:52.956 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:52.958 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:52.959 | INFO     | __main__:process_document:45 - Question: Does open access eliminate price barriers?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 588.01ms
# 2025-01-29 13:54:53.555 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:53.557 | INFO     | __main__:process_document:49 - Answer: Generation Error
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 585.27ms
# 2025-01-29 13:54:53.559 | INFO     | __main__:process_document:45 - Question: Are publication fees required for all open access journals?
# 2025-01-29 13:54:54.227 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 658.84ms
# 2025-01-29 13:54:54.229 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:54.230 | INFO     | __main__:process_document:45 - Question: In what year did the Bill and Melinda Gates foundation implement an open access policy?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 633.02ms
# 2025-01-29 13:54:54.872 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:54.874 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:54.875 | INFO     | __main__:process_document:45 - Question: Are Gold Open Access and Green Open Access mutually exclusive.
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 557.19ms
# 2025-01-29 13:54:55.438 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:55.439 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:55.444 | INFO     | __main__:<cell line: 0>:12 - Downloading document https://commission.europa.eu/document/download/1654ca52-ec72-4bae-ba40-d2fc0f3d71ae_en?filename=mit-1-performance-and-technical-performance-specification-v1-2_en.pdf
# 2025-01-29 13:54:55.446 | INFO     | __main__:<cell line: 0>:18 - File 1654ca52-ec72-4bae-ba40-d2fc0f3d71ae_en?filename=mit-1-performance-and-technical-performance-specification-v1-2_en.pdf.pdf already exists
# 2025-01-29 13:54:55.451 | INFO     | __main__:process_document:40 - Predicting
# 2025-01-29 13:54:55.454 | INFO     | __main__:process_document:45 - Question: Which type of water must be supplied in a toilet sink? -A: hot -B: cold -C: hot and cold
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 633.98ms
# 2025-01-29 13:54:56.098 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:56.102 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:56.103 | INFO     | __main__:process_document:45 - Question: In which type of parkings must a carbon monoxide detector be installed? -A: indoor -B: underground -C: indoor or underground
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 584.96ms
# 2025-01-29 13:54:56.697 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:56.699 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:56.701 | INFO     | __main__:process_document:45 - Question: What percentage is the daylight factor required for façades with exterior obstructions? -A: 0.7% -B: 80% -C: 0.77%
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 710.18ms
# 2025-01-29 13:54:57.422 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:57.424 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:57.426 | INFO     | __main__:process_document:45 - Question: What fire resistance must vertical partitions have? -A: EI30 -B: EI60 -C: EI90
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 583.42ms
# 2025-01-29 13:54:58.019 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:58.021 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:58.025 | INFO     | __main__:<cell line: 0>:12 - Downloading document https://docs.nvidia.com/cuda/pdf/CUDA_C_Programming_Guide.pdf
# 2025-01-29 13:54:58.027 | INFO     | __main__:<cell line: 0>:18 - File CUDA_C_Programming_Guide.pdf.pdf already exists
# 2025-01-29 13:54:58.028 | INFO     | __main__:process_document:40 - Predicting
# 2025-01-29 13:54:58.030 | INFO     | __main__:process_document:45 - Question: What is the maximum number of threads within a thread block?
# 2025-01-29 13:54:58.759 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 715.90ms
# 2025-01-29 13:54:58.763 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:58.765 | INFO     | __main__:process_document:45 - Question: Can you identify a thread with a four-dimensional index?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 736.45ms
# 2025-01-29 13:54:59.509 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:54:59.513 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:54:59.514 | INFO     | __main__:process_document:45 - Question: In the offline compilation process using nvcc, what happens to the device code? -A: It is directly executed on the host CPU. -B:  It is transformed into assembly and/or binary form. -C:  It is ignored and not used in the final application.
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 684.31ms
# 2025-01-29 13:55:00.210 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:55:00.213 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:55:00.214 | INFO     | __main__:process_document:45 - Question: What are the two ways the host code can be output after being processed by nvcc? -A: As executable machine code, or a interpreted scripting language file. -B: As C++ code for later compilation, or as object code directly. -C: As an encrypted file or in a platform specific assembly format.
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 583.52ms
# 2025-01-29 13:55:00.815 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:55:00.816 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:55:00.818 | INFO     | __main__:process_document:45 - Question: What is the primary purpose of just-in-time (JIT) compilation? -A: To convert host code into device code for execution on the GPU. -B: To optimize the performance of host code before it is compiled. -C: To compile PTX code into binary code at runtime by the device driver.
# 2025-01-29 13:55:01.414 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:55:01.415 | INFO     | __main__:process_document:49 - Answer: Generation Error
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 585.33ms
# 2025-01-29 13:55:01.418 | INFO     | __main__:process_document:45 - Question: What happens to the compiled binary code after JIT compilation by the device driver? -A: It is cached for later use and to avoid recompilation. -B: It's directly interpreted and doesn't need to be cached. -C: It is deleted after use to save space.
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 583.50ms
# 2025-01-29 13:55:02.012 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:55:02.017 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:55:02.019 | INFO     | __main__:process_document:45 - Question: When are virtual addresses assigned to graph allocations? -A: At the moment the graph is executed in the GPU. -B: When the allocation is actually being used by the execution. -C: When the node is created.
# 2025-01-29 13:55:02.690 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:55:02.691 | INFO     | __main__:process_document:49 - Answer: Generation Error
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 660.22ms
# 2025-01-29 13:55:02.694 | INFO     | __main__:process_document:45 - Question: What do graph memory nodes represent in a CUDA graph? -A: Actions like allocating or freeing the memmory. -B: Code that executes on the CPU to allocate memory. -C: The control flow and branching within a graph.
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 710.62ms
# 2025-01-29 13:55:03.415 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:55:03.417 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:55:03.419 | INFO     | __main__:process_document:45 - Question: When does a graph allocation's lifetime end? -A: Only when the application shuts down. -B: When the execution reaches the freeing graph node, `cudaFreeAsync()`, or `cudaFree()`. -C: Only when the graph is destroyed.
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 710.13ms
# 2025-01-29 13:55:04.140 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:55:04.142 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:55:04.144 | INFO     | __main__:process_document:45 - Question: How must operations accessing graph memory be ordered within a graph? -A: Before the allocation node and after the freeing node. -B: After any previous GPU execution. -C: After the allocation node and before the freeing operation.
# 2025-01-29 13:55:04.819 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:55:04.821 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:55:04.823 | INFO     | __main__:process_document:45 - Question: What is the primary benefit of Lazy Loading? -A: It reduces memory overhead and saves initalization time. -B: It allows programs to load all kernels faster during initialization. -C: It makes CUDA programs easier to debug and optimize.
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 673.64ms
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 658.60ms
# 2025-01-29 13:55:05.500 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:55:05.502 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:55:05.504 | INFO     | __main__:process_document:45 - Question: Can you enable lazy loading by setting the env var `CUDA_MODULE_DATA_LOADING`?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 684.66ms
# 2025-01-29 13:55:06.206 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# ...
# 2025-01-29 13:55:17.353 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:55:17.355 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:55:17.357 | INFO     | __main__:process_document:45 - Question: After taking a landmark tile, do you reveal a new tile and the end of your turn?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 683.50ms
# 2025-01-29 13:55:18.050 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:55:18.052 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:55:18.054 | INFO     | __main__:process_document:45 - Question: Can a player pay coins to compensate for missing skill symbols in a Landmark Tile?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 659.33ms
# 2025-01-29 13:55:18.721 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:55:18.723 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:55:18.727 | INFO     | __main__:process_document:45 - Question: If a player is missing 2 skill symbols, how many coins must they pay to the reserve?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 609.49ms
# 2025-01-29 13:55:19.345 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:55:19.347 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:55:19.349 | INFO     | __main__:process_document:45 - Question: Can you use a symbol more than once per turn?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 709.21ms
# 2025-01-29 13:55:20.068 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:55:20.071 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:55:20.073 | INFO     | __main__:process_document:45 - Question: Which type of cards provide coins? -A: Gray -B: Yellow -C: Blue
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 684.96ms
# 2025-01-29 13:55:20.764 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:55:20.766 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:55:20.770 | INFO     | __main__:process_document:45 - Question: During which chapter the purple cards become available? -A: Chapter 1 -B: Chapter 2 -C: Chapter 3
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 632.86ms
# 2025-01-29 13:55:21.409 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:55:21.411 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:55:21.413 | INFO     | __main__:process_document:45 - Question: If you place or move an unit and an enemy fortress is present, does it trigger a conflict?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 659.19ms
# 2025-01-29 13:55:22.081 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:55:22.084 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:55:22.086 | INFO     | __main__:process_document:45 - Question: Can the game end in a tie?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 607.59ms
# 2025-01-29 13:55:22.701 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:55:22.703 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:55:22.705 | INFO     | __main__:process_document:45 - Question: In how many regions do you need to be present to win the game?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 709.04ms
# 2025-01-29 13:55:23.422 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:55:23.423 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:55:23.435 | INFO     | __main__:<cell line: 0>:12 - Downloading document https://github.com/mozilla-ai/structured-qa/releases/download/0.3.2/is_eotn_rulebook.pdf
# 2025-01-29 13:55:23.437 | INFO     | __main__:<cell line: 0>:18 - File is_eotn_rulebook.pdf.pdf already exists
# 2025-01-29 13:55:23.439 | INFO     | __main__:process_document:40 - Predicting
# 2025-01-29 13:55:23.441 | INFO     | __main__:process_document:45 - Question: What is the maximum number of cards a player may acquire during the lookout phase?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 709.39ms
# 2025-01-29 13:55:24.159 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:55:24.160 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:55:24.162 | INFO     | __main__:process_document:45 - Question: Is there a limit to the number of cards a player may have in their hand?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 614.42ms
# 2025-01-29 13:55:24.783 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:55:24.784 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:55:24.787 | INFO     | __main__:process_document:45 - Question: Can you raid the locations of a player that has passed during the action phase?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 659.58ms
# 2025-01-29 13:55:25.454 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:55:25.455 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:55:25.458 | INFO     | __main__:process_document:45 - Question: How many points in the scoreboard must be reached during the Action phase to trigger the final round?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 860.42ms
# 2025-01-29 13:55:26.327 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:55:26.329 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:55:26.333 | INFO     | __main__:process_document:45 - Question: Can players conquer and pillage the same island during the expedition phase?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 683.94ms
# 2025-01-29 13:55:27.024 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:55:27.027 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:55:27.029 | INFO     | __main__:process_document:45 - Question: Do you need a fish to conquer a distant island?
# 2025-01-29 13:55:27.696 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:55:27.697 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:55:27.698 | INFO     | __main__:process_document:45 - Question: How many victory points you get from each conquered island?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 669.67ms
# 2025-01-29 13:55:28.420 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:55:28.421 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:55:28.423 | INFO     | __main__:process_document:45 - Question: Is there a cleanup phase in the final round?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 721.91ms
# 2025-01-29 13:55:29.116 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:55:29.117 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:55:29.119 | INFO     | __main__:process_document:45 - Question: How many victory points are granted by a built Field Location card that work as an upgrade?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 687.25ms
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 683.55ms
# 2025-01-29 13:55:29.813 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:55:29.814 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:55:29.817 | INFO     | __main__:process_document:45 - Question: Do you need a ship to be on the expedition board to use a card that allos to pillage or conquer right away?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 607.97ms
# 2025-01-29 13:55:30.434 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:55:30.436 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:55:30.438 | INFO     | __main__:process_document:45 - Question: Can you use the raid action without a Raze token?
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 632.87ms
# 2025-01-29 13:55:31.077 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# 2025-01-29 13:55:31.079 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:55:31.080 | INFO     | __main__:process_document:45 - Question: Can the game end in a tie?
# 2025-01-29 13:55:31.734 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 644.82ms
# 2025-01-29 13:55:31.737 | INFO     | __main__:process_document:49 - Answer: Generation Error
# 2025-01-29 13:55:31.746 | INFO     | __main__:process_document:45 - Question: If player 1 has 30 Victory points and 4 workers and player 2 has 30 Victory points and 3 workers, who wins the game? -A: Player 1 -B: Player 2 -C: It's a tie
# 2025-01-29 13:55:32.540 | ERROR    | structured_qa.workflow:find_retrieve_answer:83 - Failed to generate completion: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 763.87ms
# 2025-01-29 13:55:32.551 | INFO     | __main__:process_document:49 - Answer: Generation Error

# %%
results = pd.read_csv("results.csv")
results.loc[results["answer"] != results["pred_answer"]]
# Out:
#     Unnamed: 0                                           document  \
# 0            0                   https://arxiv.org/pdf/1706.03762
# 1            1                   https://arxiv.org/pdf/1706.03762
# 2            2                   https://arxiv.org/pdf/1706.03762
# 3            3                   https://arxiv.org/pdf/1706.03762
# 4            4                   https://arxiv.org/pdf/1706.03762
# ..         ...                                                ...
# 94          94  https://aiindex.stanford.edu/wp-content/upload...
# 95          95  https://aiindex.stanford.edu/wp-content/upload...
# 96          96  https://aiindex.stanford.edu/wp-content/upload...
# 97          97  https://aiindex.stanford.edu/wp-content/upload...
# 98          98  https://aiindex.stanford.edu/wp-content/upload...
#
#                                    section  \
# 0                     3 Model Architecture
# 1           3.1 Encoder and Decoder Stacks
# 2           3.1 Encoder and Decoder Stacks
# 3               3.2.2 Multi-Head Attention
# 4               3.4 Embeddings and Softmax
# ..                                     ...
# 94  LLM Tokenization Introduces Unfairness
# 95                         U.S. Regulation
# 96                         U.S. Regulation
# 97                                  Europe
# 98                                  Europe
#
#                                              question answer  \
# 0   What type of architecture does the model use? ...      C
# 1                How many layers compose the encoder?      6
# 2                How many layers compose the decoder?      6
# 3         How many parallel attention heads are used?      8
# 4   Does the final model use learned embeddings fo...    YES
# ..                                                ...    ...
# 94  What are the three major inequalities resultin...      B
# 95  How many AI-related regulations were enacted i...     25
# 96  Which of the following was identified as a hig...      B
# 97  Which country had the highest proportion of fe...      B
# 98  Which countries reported the smallest proporti...      C
#
#          pred_answer  pred_section
# 0   GENERATION ERROR           NaN
# 1   GENERATION ERROR           NaN
# 2   GENERATION ERROR           NaN
# 3   GENERATION ERROR           NaN
# 4   GENERATION ERROR           NaN
# ..               ...           ...
# 94  GENERATION ERROR           NaN
# 95  GENERATION ERROR           NaN
# 96  GENERATION ERROR           NaN
# 97  GENERATION ERROR           NaN
# 98  GENERATION ERROR           NaN
#
# [99 rows x 7 columns]

# %%
accuracy = sum(results["answer"] == results["pred_answer"]) / len(results)
accuracy
# Out:
# 0.0
